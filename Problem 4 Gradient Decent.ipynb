# %%
import numpy as np

datasetFile = open('./train.csv', 'r')

price = []
bedrooms = []
bathrooms = []
sqft_living = []
sqft_lot = []
floors = []
waterfront = []
view = []
condition = []
grade = []
sqft_above = []
sqft_basement = []
yr_built = []
yr_renovated = []
zipcode = []
lat = []
long = []
sqft_living15 = []
sqft_lot15 = []
datasetFile.readline()

for line in datasetFile:
    splitedLine = line.split(',')
    price.append(float(splitedLine[1]))
    bedrooms.append(float(splitedLine[2]))
    bathrooms.append(float(splitedLine[3]))
    sqft_living.append(float(splitedLine[4]))
    sqft_lot.append(float(splitedLine[5]))
    floors.append(float(splitedLine[6]))
    waterfront.append(float(splitedLine[7]))
    view.append(float(splitedLine[8]))
    condition.append(float(splitedLine[9]))
    grade.append(float(splitedLine[10]))
    sqft_above.append(float(splitedLine[11]))
    sqft_basement.append(float(splitedLine[12]))
    yr_built.append(float(splitedLine[13]))
    yr_renovated.append(float(splitedLine[14]))
    zipcode.append(float(splitedLine[15]))
    lat.append(float(splitedLine[16]))
    long.append(float(splitedLine[17]))
    sqft_living15.append(float(splitedLine[18]))
    sqft_lot15.append(float(splitedLine[19]))
print("Loaded train file into array")
# Out:
# Loaded train file into array

# %%
import math

def normalize(toNormalize):
    listSquared = np.square(toNormalize)
    #Calculate mean
    mean = np.sum(toNormalize)/len(toNormalize)
    
    #Calculate Standard Deviation
    difference = np.square(toNormalize-mean)
    variance = np.sum(difference)/len(toNormalize)
    variance = math.sqrt(variance)
    
    #Normalize
    toNormalize = toNormalize - mean
    toNormalize = np.true_divide(toNormalize,variance)
    return toNormalize, mean, variance

normalizedBedrooms = normalize(bedrooms)
normalizedBathrooms = normalize(bathrooms)
normalizedSqft_living = normalize(sqft_living)
normalizedSqft_lot = normalize(sqft_lot)
normalizedFloors = normalize(floors)
normalizedWaterfront = normalize(waterfront)
normalizedView = normalize(view)
normalizedCondition = normalize(condition)
normalizedGrade = normalize(grade)
normalizedSqft_above = normalize(sqft_above)
normalizedSqft_basement = normalize(sqft_basement)
normalizedYr_built = normalize(yr_built)
normalizedYr_renovated = normalize(yr_renovated)
normalizedZipcode = normalize(zipcode)
normalizedLat = normalize(lat)
normalizedLong = normalize(long)
normalizedSqft_living15 = normalize(sqft_living15)
normalizedSqft_lot15 = normalize(sqft_lot15)
print("Normalized train features")
# Out:
# Normalized train features

# %%
datasetFile = open('./test.csv', 'r')
test_price = []
test_bedrooms = []
test_bathrooms = []
test_sqft_living = []
test_sqft_lot = []
test_floors = []
test_waterfront = []
test_view = []
test_condition = []
test_grade = []
test_sqft_above = []
test_sqft_basement = []
test_yr_built = []
test_yr_renovated = []
test_zipcode = []
test_lat = []
test_long = []
test_sqft_living15 = []
test_sqft_lot15 = []
datasetFile.readline()

for line in datasetFile:
    splitedLine = line.split(',')
    test_price.append(float(splitedLine[3]))
    test_bedrooms.append(float(splitedLine[4]))
    test_bathrooms.append(float(splitedLine[5]))
    test_sqft_living.append(float(splitedLine[6]))
    test_sqft_lot.append(float(splitedLine[7]))
    test_floors.append(float(splitedLine[8]))
    test_waterfront.append(float(splitedLine[9]))
    test_view.append(float(splitedLine[10]))
    test_condition.append(float(splitedLine[11]))
    test_grade.append(float(splitedLine[12]))
    test_sqft_above.append(float(splitedLine[13]))
    test_sqft_basement.append(float(splitedLine[14]))
    test_yr_built.append(float(splitedLine[15]))
    test_yr_renovated.append(float(splitedLine[16]))
    test_zipcode.append(float(splitedLine[17]))
    test_lat.append(float(splitedLine[18]))
    test_long.append(float(splitedLine[19]))
    test_sqft_living15.append(float(splitedLine[20]))
    test_sqft_lot15.append(float(splitedLine[21]))
print("Loaded test file into array")
# Out:
# Loaded test file into array

# %%
def normalizeTo(toNormalize, mean, var):
    #Normalize
    normalized = list()    
    for a in toNormalize:
        toAdd = (a-mean)/var
        normalized.append(toAdd)
        
    return normalized

test_normalized_bedrooms = normalizeTo(test_bedrooms,normalizedBedrooms[1],normalizedBedrooms[2])
test_normalized_bathrooms = normalizeTo(test_bathrooms, normalizedBathrooms[1], normalizedBathrooms[2])
test_normalized_sqft_living = normalizeTo(test_sqft_living, normalizedSqft_living[1], normalizedSqft_living[2])
test_normalized_sqft_lot = normalizeTo(test_sqft_lot, normalizedSqft_lot[1], normalizedSqft_lot[2])
test_normalized_floors = normalizeTo(test_floors, normalizedFloors[1], normalizedFloors[2])
test_normalized_waterfront = normalizeTo(test_waterfront, normalizedWaterfront[1], normalizedWaterfront[2])
test_normalized_view = normalizeTo(test_view, normalizedView[1], normalizedView[2])
test_normalized_condition = normalizeTo(test_condition, normalizedCondition[1], normalizedCondition[2])
test_normalized_grade = normalizeTo(test_grade, normalizedGrade[1], normalizedGrade[2])
test_normalized_sqft_above = normalizeTo(test_sqft_above, normalizedSqft_above[1], normalizedSqft_above[2])
test_normalized_sqft_basement = normalizeTo(test_sqft_basement, normalizedSqft_basement[1], normalizedSqft_basement[2])
test_normalized_yr_built = normalizeTo(test_yr_built, normalizedYr_built[1], normalizedYr_built[2])
test_normalized_yr_renovated = normalizeTo(test_yr_renovated, normalizedYr_renovated[1], normalizedYr_renovated[2])
test_normalized_zipcode = normalizeTo(test_zipcode, normalizedZipcode[1], normalizedZipcode[2])
test_normalized_lat = normalizeTo(test_lat, normalizedLat[1], normalizedLat[2])
test_normalized_long = normalizeTo(test_long, normalizedLong[1], normalizedLong[2])
test_normalized_sqft_living15 = normalizeTo(test_sqft_living15, normalizedSqft_living15[1], normalizedSqft_living15[2])
test_normalized_sqft_lot15 = normalizeTo(test_sqft_lot15, normalizedSqft_lot15[1], normalizedSqft_lot15[2])
print("Normalized test features")
# Out:
# Normalized test features

# %%
from sklearn.metrics import mean_squared_error

def calculateLossSlope(features, pred_output, actual_output):
    multiplied = np.matmul(np.transpose(features), pred_output - actual_output)
    return multiplied * (2/len(features))

def gradient_decent(features, expected_output, learningRate, numberOfIterations):
    #theta = np.random.randn(len(features[0]))
    theta = np.ones(len(features[0]))
    for i in range(0, numberOfIterations):   
        pred_output = np.matmul(features,theta)
        slope = calculateLossSlope(features, pred_output, expected_output)
        theta = theta - learningRate*slope
    return theta


ones = np.ones(len(bedrooms))
features = np.array([ones,normalizedBedrooms[0],  normalizedBathrooms[0],  normalizedSqft_living[0],  
                    normalizedSqft_lot[0],  normalizedFloors[0],  normalizedWaterfront[0],  
                    normalizedView[0],  normalizedCondition[0], normalizedGrade[0],  normalizedSqft_above[0],  
                    normalizedSqft_basement[0], normalizedYr_built[0],  normalizedYr_renovated[0],  
                    normalizedZipcode[0], normalizedLat[0], normalizedLong[0],  normalizedSqft_living15[0],  
                    normalizedSqft_lot15[0]])
features = np.transpose(features)

testFeatures = np.array([ones, test_normalized_bedrooms, test_normalized_bathrooms, test_normalized_sqft_living, test_normalized_sqft_lot, test_normalized_floors, 
                               test_normalized_waterfront, test_normalized_view, test_normalized_condition, test_normalized_grade, test_normalized_sqft_above, 
                               test_normalized_sqft_basement, test_normalized_yr_built, test_normalized_yr_renovated, test_normalized_zipcode, test_normalized_lat, 
                               test_normalized_long, test_normalized_sqft_living15, test_normalized_sqft_lot15])
testFeatures = np.transpose(testFeatures)

learningRates = [0.05, 0.075, 0.1, 0.125, 0.15]
repeatValues = [20, 30, 40, 50, 60]

for rate in learningRates:
    for repetition in repeatValues:
        #Gradient Decent
        theta = gradient_decent(features, price, rate, repetition)
        
        #Predicte with train features
        price_pred = np.matmul(features,theta)

        print("Gradient Decent Linear Regression with Learning Rate %.3f and with %d repetition" % (rate, repetition))
        # The metrics
        print("Coefficients: ")
        print(theta)
        
        print("MSE: %.2f" % mean_squared_error(price, price_pred))

        residual = (price-price_pred)
        residual = np.square(residual)
        rss = np.sum(residual)
        average_price = np.sum(price)/len(price)
        totalSumOfSquare = np.square(price-average_price)
        totalSumOfSquare = np.sum(totalSumOfSquare)
        rSquared = 1 - float(rss)/float(totalSumOfSquare)
        print("R^2: %.8f" % rSquared)
        print()

    print("Gradient Decent Linear Regression with Learning Rate %.3f and Test Set" % rate)
    price_pred = np.matmul(testFeatures,theta)
    print("MSE: %.2f" % mean_squared_error(test_price, price_pred))
    residual = (test_price-price_pred)
    residual = np.square(residual)
    rss = np.sum(residual)
    average_price = np.sum(test_price)/len(test_price)
    totalSumOfSquare = np.square(test_price-average_price)
    totalSumOfSquare = np.sum(totalSumOfSquare)
    rSquared = 1 - float(rss)/float(totalSumOfSquare)
    print("R^2: %.4f" % rSquared)
    print()
    print()
# Out:
# Gradient Decent Linear Regression with Learning Rate 0.050 and with 20 repetition
# Coefficients:
# [457144.66105963  -4254.48820845  18785.02693152  56860.97037315
#    2481.81045018  10480.28484331  56592.38961384  52782.93231879
#   16134.35699869  66463.41537353  46491.79866176  30509.65253403
#  -46832.9020636   23045.73867024  -6319.24057102  76182.89270831
#  -13404.03906128  54616.11801297  -1292.74884011]
# MSE: 35881042095.27
# R^2: 0.68836266
#
# Gradient Decent Linear Regression with Learning Rate 0.050 and with 30 repetition
# Coefficients:
# [498353.88879429  -8930.18420364  16679.00627516  57125.20973827
#    2833.55869583  10289.60645475  59966.67623584  51649.64390204
#   15731.8920628   72290.18095129  48088.44490043  28232.31280362
#  -54129.07940096  22134.58623126 -12954.46198436  81262.42031581
#  -12539.65616078  54243.22382427  -3547.94610546]
# MSE: 31940929115.44
# R^2: 0.72258370
#
# Gradient Decent Linear Regression with Learning Rate 0.050 and with 40 repetition
# Coefficients:
# [512722.65803854 -11202.29608856  15984.99369748  57221.93940682
#    3605.94047637  10249.85889302  61519.6775228   50628.66580562
#   15048.491214    76508.45857711  48762.18319235  27242.25262228
#  -58893.20697596  21110.17940823 -17094.47481236  83108.71801188
#  -12290.38716277  52960.34945308  -5029.26560206]
# MSE: 31358443507.91
# R^2: 0.72764275
#
# Gradient Decent Linear Regression with Learning Rate 0.050 and with 50 repetition
# Coefficients:
# [517732.73808478 -12397.69617486  15921.96967026  57231.63636599
#    4486.8739268   10326.18669298  62332.37870674  49969.29566305
#   14335.79328174  79719.03466974  49004.12171083  26837.41631512
#  -62214.68655611  20233.74837922 -19623.21539618  83705.59833297
#  -12255.86769782  51447.01589847  -6070.72427837]
# MSE: 31234230525.07
# R^2: 0.72872158
#
# Gradient Decent Linear Regression with Learning Rate 0.050 and with 60 repetition
# Coefficients:
# [519479.64498008 -13071.447276    16122.83326712  57185.87150005
#    5335.80765179  10450.34134906  62791.67689832  49586.99206779
#   13701.6087158   82228.25643249  49043.1074048   26678.98214723
#  -64618.25926351  19527.9684103  -21194.68168871  83809.33782993
#  -12229.16141627  49974.37369119  -6857.69264492]
# MSE: 31188419058.42
# R^2: 0.72911947
#
# Gradient Decent Linear Regression with Learning Rate 0.050 and Test Set
# MSE: 57498123884.75
# R^2: 0.6551
#
#
# Gradient Decent Linear Regression with Learning Rate 0.075 and with 20 repetition
# Coefficients:
# [500243.83782427  -9104.50369321  16574.87000745  57135.0857862
#    2802.99057606  10276.89068969  60092.41268836  51629.37152137
#   15751.30945388  72407.82123878  48155.96569972  28133.44917651
#  -54311.36830985  22136.72152682 -13151.51368091  81490.16594577
#  -12488.07827229  54307.32266017  -3605.89409828]
# MSE: 31852442887.29
# R^2: 0.72335223
#
# Gradient Decent Linear Regression with Learning Rate 0.075 and with 30 repetition
# Coefficients:
# [516443.68114294 -11969.80857864  15859.01387934  57243.77213653
#    4042.56252405  10268.73195229  62041.06429126  50219.2766549
#   14681.91719951  78310.13156989  48951.54086606  26953.44837484
#  -60822.02543601  20630.07735862 -18651.52882476  83584.41650292
#  -12256.60902956  52215.50339191  -5627.74437707]
# MSE: 31270388040.51
# R^2: 0.72840754
#
# Gradient Decent Linear Regression with Learning Rate 0.075 and with 40 repetition
# Coefficients:
# [519633.01564672 -13111.32608957  16109.92977256  57190.30571243
#    5349.34726891  10450.22263392  62818.68955721  49559.84739409
#   13684.09375979  82305.67431716  49056.24333356  26664.69702758
#  -64710.26237964  19505.14863986 -21279.34966211  83834.7942062
#  -12237.5829665   49951.60945549  -6880.86046591]
# MSE: 31187017377.94
# R^2: 0.72913164
#
# Gradient Decent Linear Regression with Learning Rate 0.075 and with 50 repetition
# Coefficients:
# [520260.9139774  -13631.15661024  16572.51763993  57068.92203068
#    6461.9860952   10639.13234064  63175.53271827  49312.4588273
#   12940.19352717  85130.22794595  48953.20233275  26606.21432686
#  -67198.40041456  18720.36057415 -22606.62852412  83668.14877715
#  -12105.18893877  48013.49663748  -7777.38298556]
# MSE: 31155028726.08
# R^2: 0.72940947
#
# Gradient Decent Linear Regression with Learning Rate 0.075 and with 60 repetition
# Coefficients:
# [520384.53108723 -13888.28051264  17016.72675923  56936.45478556
#    7351.80078635  10777.70148637  63357.23894939  49255.78193458
#   12426.14551336  87172.02364164  48808.58321566  26598.75980404
#  -68862.77021194  18180.41192678 -23314.77744458  83450.67746601
#  -11884.64208542  46473.04577992  -8469.07898197]
# MSE: 31138988973.07
# R^2: 0.72954878
#
# Gradient Decent Linear Regression with Learning Rate 0.075 and Test Set
# MSE: 57301734329.78
# R^2: 0.6563
#
#
# Gradient Decent Linear Regression with Learning Rate 0.100 and with 20 repetition
# Coefficients:
# [514414.87099487 -11407.84221013  15862.89506346  57239.91789463
#    3585.99541439  10224.29272309  61659.01324641  50548.72127395
#   15053.18197083  76708.98209937  48846.13662412  27130.55093169
#  -59179.39411759  21076.25033562 -17420.23255214  83342.8377944
#  -12251.73179868  53001.43877022  -5116.88672587]
# MSE: 31327929673.60
# R^2: 0.72790778
#
# Gradient Decent Linear Regression with Learning Rate 0.100 and with 30 repetition
# Coefficients:
# [519770.59287789 -13150.20184243  16097.90120056  57194.76879266
#    5363.52130711  10450.41093929  62845.0608814   49532.55766931
#   13665.82201727  82383.22665532  49068.93612847  26651.24522833
#  -64802.03574392  19481.93843495 -21363.21760269  83858.34462395
#  -12247.10816274  49927.79738561  -6903.66227303]
# MSE: 31185703166.20
# R^2: 0.72914305
#
# Gradient Decent Linear Regression with Learning Rate 0.100 and with 40 repetition
# Coefficients:
# [520345.65913625 -13753.95508488  16732.60103471  57024.09891064
#    6801.81037744  10696.7520033   63260.4717378   49267.17673365
#   12727.47385766  85945.48713448  48906.51047849  26599.76148281
#  -67887.8577376   18498.16059765 -22933.85005388  83593.80848107
#  -12044.04703789  47421.61002575  -8042.22039686]
# MSE: 31147982334.11
# R^2: 0.72947067
#
# Gradient Decent Linear Regression with Learning Rate 0.100 and with 50 repetition
# Coefficients:
# [520407.40640556 -13994.70692813  17280.14131532  56852.84181971
#    7854.73459569  10845.54890384  63436.11155073  49261.82281824
#   12165.03297799  88266.85611877  48715.13939114  26597.84045087
#  -69714.34393606  17902.90205801 -23624.03010104  83317.96678315
#  -11720.29065394  45611.39280938  -8861.99432882]
# MSE: 31132474420.79
# R^2: 0.72960536
#
# Gradient Decent Linear Regression with Learning Rate 0.100 and with 60 repetition
# Coefficients:
# [520414.03646812 -14097.45241265  17677.73297863  56718.81895249
#    8612.10426899  10916.59301304  63523.81885213  49327.50209254
#   11831.88014273  89804.17772026  48568.89927485  26590.16289019
#  -70839.0392002   17538.54205261 -23950.36880323  83122.18766636
#  -11406.83098566  44350.18172448  -9470.62597831]
# MSE: 31125642186.13
# R^2: 0.72966470
#
# Gradient Decent Linear Regression with Learning Rate 0.100 and Test Set
# MSE: 57225232861.19
# R^2: 0.6568
#
#
# Gradient Decent Linear Regression with Learning Rate 0.125 and with 20 repetition
# Coefficients:
# [518764.49143643 -12582.47271412  15829.76570532  57253.48320584
#    4503.31419845  10308.50130457  62457.52714884  49860.92077807
#   14301.545513    79982.26730324  49076.84835741  26753.00427227
#  -62557.20284719  20165.87070229 -19978.91348228  83872.22008104
#  -12263.02409671  51423.92213873  -6163.73342615]
# MSE: 31224163324.77
# R^2: 0.72880902
#
# Gradient Decent Linear Regression with Learning Rate 0.125 and with 30 repetition
# Coefficients:
# [520321.89740977 -13672.41368104  16578.29190567  57070.36401521
#    6500.69611944  10648.73528299  63202.95708472  49281.73952516
#   12900.34800468  85260.52278978  48958.53142129  26599.716158
#  -67333.92030754  18679.02219231 -22705.89898396  83672.26827045
#  -12121.15347382  47944.28042036  -7810.53047149]
# MSE: 31153803854.56
# R^2: 0.72942011
#
# Gradient Decent Linear Regression with Learning Rate 0.125 and with 40 repetition
# Coefficients:
# [520409.60041396 -14002.85966742  17290.0004102   56850.32972273
#    7873.37894003  10850.5470633   63441.25100941  49257.86628938
#   12150.7468372   88315.6977259   48711.97649193  26598.4356431
#  -69757.63595537  17888.56038016 -23645.74741218  83312.49198439
#  -11719.25950501  45576.61925165  -8875.1225912 ]
# MSE: 31132218642.72
# R^2: 0.72960758
#
# Gradient Decent Linear Regression with Learning Rate 0.125 and with 50 repetition
# Coefficients:
# [520414.53927838 -14115.87890862  17765.38202535  56688.6956541
#    8780.8084956   10929.23166026  63541.1659533   49346.39342944
#   11763.08067367  90136.46552454  48536.58479899  26587.46512517
#  -71075.83667792  17462.17031583 -24012.07753322  83079.72627708
#  -11331.92691364  44073.44543925  -9608.13843357]
# MSE: 31124516095.68
# R^2: 0.72967448
#
# Gradient Decent Linear Regression with Learning Rate 0.125 and with 60 repetition
# Coefficients:
# [520414.81740319 -14156.87830956  18057.28078721  56587.86047038
#    9381.57008882  10948.71692174  63592.80200734  49433.68354381
#   11556.85587188  91232.29698768  48433.9293435   26568.77189657
#  -71816.25113164  17225.71636196 -24168.53566949  82943.13953499
#  -11046.40978495  43135.0813215  -10114.53509306]
# MSE: 31121657579.44
# R^2: 0.72969931
#
# Gradient Decent Linear Regression with Learning Rate 0.125 and Test Set
# MSE: 57192912925.20
# R^2: 0.6570
#
#
# Gradient Decent Linear Regression with Learning Rate 0.150 and with 20 repetition
# Coefficients:
# [519999.58400773 -13225.80674447  16075.31035122  57202.34425198
#    5393.33443218  10451.0944545   62895.75399719  49477.30172196
#   13626.99505908  82537.42193773  49091.55378834  26626.53181849
#  -64985.63997421  19434.37032284 -21527.6197748   83899.51301595
#  -12270.31549161  49875.56803341  -6948.64846011]
# MSE: 31183282289.22
# R^2: 0.72916408
#
# Gradient Decent Linear Regression with Learning Rate 0.150 and with 30 repetition
# Coefficients:
# [520403.1042155  -13923.16029328  17042.74985005  56931.46573014
#    7410.64636453  10794.33214004  63379.54930055  49233.84448737
#   12375.54593366  87336.6495385   48802.89816365  26598.89664965
#  -69017.09948649  18129.93026697 -23404.49041239  83437.26060488
#  -11891.36669872  46364.27775096  -8511.23712779]
# MSE: 31137919123.15
# R^2: 0.72955807
#
# Gradient Decent Linear Regression with Learning Rate 0.150 and with 40 repetition
# Coefficients:
# [520414.50266262 -14105.50513004  17696.99819139  56712.55279226
#    8644.13002308  10923.24023893  63529.08321982  49327.11995385
#   11812.26924965  89880.87974758  48561.2826791   26591.1693124
#  -70900.89864778  17518.14121459 -23973.56548299  83111.94099751
#  -11396.92619223  44290.76403268  -9494.00848806]
# MSE: 31125376926.67
# R^2: 0.72966701
#
# Gradient Decent Linear Regression with Learning Rate 0.150 and with 50 repetition
# Coefficients:
# [520414.82464054 -14158.27062196  18064.38341031  56585.21347134
#    9393.61994077  10949.98076164  63594.02973805  49435.1428518
#   11551.37997762  91258.21420256  48431.00834065  26568.67757539
#  -71835.02708883  17219.67658639 -24173.32845009  82939.72203346
#  -11040.50395616  43113.85813102 -10124.06327415]
# MSE: 31121608083.94
# R^2: 0.72969974
#
# Gradient Decent Linear Regression with Learning Rate 0.150 and with 60 repetition
# Coefficients:
# [520414.83373562 -14175.17999159  18260.61422092  56521.05747184
#    9852.34604816  10944.61945205  63628.31164042  49510.28463483
#   11425.0451721   92007.26938514  48370.8256806   26547.79254493
#  -72310.81111222  17068.95280754 -24252.09969678  82850.44725688
#  -10823.08358923  42449.86216046 -10525.13956132]
# MSE: 31120440190.10
# R^2: 0.72970988
#
# Gradient Decent Linear Regression with Learning Rate 0.150 and Test Set
# MSE: 57177970495.03
# R^2: 0.6571
